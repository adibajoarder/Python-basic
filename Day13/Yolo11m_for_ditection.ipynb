# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.12.0.88)
# Requirement already satisfied: numpy<2.3.0,>=2 in /usr/local/lib/python3.12/dist-packages (from opencv-python) (2.0.2)

# %%
pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.246-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.9.0+cpu)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.24.0+cpu)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.31.0)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Downloading ultralytics_thop-2.0.18-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2025.11.12)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Downloading ultralytics-8.3.246-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 17.6 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.18-py3-none-any.whl (28 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.3.246 ultralytics-thop-2.0.18

# %%
import cv2
import numpy as np
from ultralytics import YOLO
from ultralytics.solutions import ObjectCounter
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
MODEL_PATH = "/content/drive/MyDrive/YOLO11m train dataset/best (1).pt"
VIDEO_PATH = "/content/drive/MyDrive/cctv.mp4/market.mp4"
OUTPUT_PATH = "/content/output_with_counting.mp4"

model = YOLO(MODEL_PATH)

# %% [markdown]
# Video setup

# %%
cap = cv2.VideoCapture(VIDEO_PATH)
if not cap.isOpened():
    raise FileNotFoundError("Video not found")

w = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
h = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))

writer = cv2.VideoWriter(
    OUTPUT_PATH,
    cv2.VideoWriter_fourcc(*"mp4v"),
    fps,
    (w, h)
)

# %% [markdown]
# Entry Exit

# %%
frame_idx = 0

first_seen = {}        # id frame index first seen
last_seen = {}         # id frame index last seen
counted_entry = set()
counted_exit = set()

MIN_FRAMES_TO_COUNT = 8     #  must stay visible
EXIT_TIMEOUT = 20           #  must be gone

# %% [markdown]
# Logic / Loop

# %%
while True:
    ret, frame = cap.read()
    if not ret:
        break

    frame_idx += 1

    results = model.track(
        frame,
        persist=True,
        tracker="bytetrack.yaml",
        conf=0.4,
        iou=0.5
    )

    visible_ids = set()

    # Define class_names here from the model
    class_names = model.names

    if results[0].boxes.id is not None:
        boxes = results[0].boxes.xyxy.cpu().numpy()
        ids = results[0].boxes.id.cpu().numpy()
        classes = results[0].boxes.cls.cpu().numpy()

        for box, tid, cls in zip(boxes, ids, classes):
            tid = int(tid)
            visible_ids.add(tid)

            if tid not in first_seen:
                first_seen[tid] = frame_idx

            last_seen[tid] = frame_idx

            # -------------------------
            # ENTRY (STABLE)
            # -------------------------
            if (
                tid not in counted_entry and
                frame_idx - first_seen[tid] >= MIN_FRAMES_TO_COUNT
            ):
                counted_entry.add(tid)

            # Gender (FIXED)
            gender = class_names[int(cls)] # Changed CLASS_NAMES to class_names

            x1, y1, x2, y2 = map(int, box)
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
            cv2.putText(
                frame,
                f"ID {tid} {gender}",
                (x1, y1 - 8),
                cv2.FONT_HERSHEY_SIMPLEX,
                0.6,
                (0, 255, 0),
                2
            )

    # -------------------------
    # EXIT (STABLE)
    # -------------------------
    for tid in counted_entry:
        if (
            tid not in visible_ids and
            tid not in counted_exit and
            frame_idx - last_seen.get(tid, 0) >= EXIT_TIMEOUT
        ):
            counted_exit.add(tid)

    entered = len(counted_entry)
    exited = len(counted_exit)
    current = entered - exited

    cv2.putText(
        frame,
        f"Entered: {entered}   Exited: {exited}   Current: {current}",
        (30, 40),
        cv2.FONT_HERSHEY_SIMPLEX,
        1,
        (0, 0, 255),
        3
    )

    writer.write(frame)
# Out:
# Streaming output truncated to the last 5000 lines.
# 0: 640x480 2 males, 1738.4ms
# Speed: 6.3ms preprocess, 1738.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 males, 1603.2ms
# Speed: 4.8ms preprocess, 1603.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 males, 1103.8ms
# Speed: 7.7ms preprocess, 1103.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 male, 1142.5ms
# Speed: 4.5ms preprocess, 1142.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 male, 1116.6ms
# Speed: 4.3ms preprocess, 1116.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 male, 1169.4ms
# Speed: 4.9ms preprocess, 1169.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 male, 1134.3ms
# Speed: 4.2ms preprocess, 1134.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 male, 1132.4ms
# Speed: 4.9ms preprocess, 1132.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 male, 1097.2ms
# Speed: 4.8ms preprocess, 1097.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 male, 1098.4ms
# Speed: 4.9ms preprocess, 1098.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 male, 1448.1ms
# Speed: 4.3ms preprocess, 1448.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 male, 1756.0ms
# Speed: 8.8ms preprocess, 1756.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 male, 1682.5ms
# Speed: 4.8ms preprocess, 1682.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 male, 1124.6ms
# Speed: 4.5ms preprocess, 1124.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 male, 
9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 3 males, 1688.7ms
# Speed: 9.0ms preprocess, 1688.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 males, 1714.4ms
# Speed: 9.9ms preprocess, 1714.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 3 males, 1086.5ms
# Speed: 5.4ms preprocess, 1086.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 3 males, 1084.1ms
# Speed: 5.7ms preprocess, 1084.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 males, 1086.4ms
# Speed: 6.5ms preprocess, 1086.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 3 males, 1098.0ms
# Speed: 4.2ms preprocess, 1098.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 3 males, 1098.6ms
# Speed: 9.5ms preprocess, 1098.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 3 males, 1088.6ms
# Speed: 5.7ms preprocess, 1088.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 3 males, 1091.1ms
# Speed: 5.3ms preprocess, 1091.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 3 males, 1083.0ms
# Speed: 5.2ms preprocess, 1083.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 3 males, 1139.6ms
# Speed: 4.8ms preprocess, 1139.6ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 3 males, 1681.6ms
# Speed: 6.2ms preprocess, 1681.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 3 males, 1697.3ms
# Speed: 9.1ms preprocess, 1697.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 3 males, 1296.6ms
# Speed: 6.5ms preprocess, 1296.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 males, 1072.0ms
# Speed: 5.8ms preprocess, 1072.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 males, 1076.8ms
# Speed: 4.4ms preprocess, 1076.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 males, 1079.5ms
# Speed: 5.3ms preprocess, 1079.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 2 males, 1069.8ms
# Speed: 4.5ms preprocess, 1069.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 2 males, 1072.6ms
# Speed: 4.5ms preprocess, 1072.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 2 males, 1076.8ms
# Speed: 5.4ms preprocess, 1076.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 2 males, 1080.4ms
# Speed: 4.6ms preprocess, 1080.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 males, 1075.9ms
# Speed: 4.5ms preprocess, 1075.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 2 males, 1529.5ms
# Speed: 6.8ms preprocess, 1529.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 males, 1678.1ms
# Speed: 7.3ms preprocess, 1678.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 males, 1595.9ms
# Speed: 7.0ms preprocess, 1595.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 males, 1060.1ms
# Speed: 5.7ms preprocess, 1060.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 males, 1064.9ms
# Speed: 4.5ms preprocess, 1064.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 males, 1066.3ms
# Speed: 7.3ms preprocess, 1066.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 males, 1078.0ms
# Speed: 4.2ms preprocess, 1078.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 males, 1081.4ms
# Speed: 6.3ms preprocess, 1081.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 males, 1114.3ms
# Speed: 4.3ms preprocess, 1114.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 2 males, 1082.3ms
# Speed: 5.8ms preprocess, 1082.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 2 males, 1080.0ms
# Speed: 6.3ms preprocess, 1080.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 2 males, 1177.2ms
# Speed: 8.2ms preprocess, 1177.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 1 male, 1662.8ms
# Speed: 5.5ms preprocess, 1662.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 1 male, 1715.5ms
# Speed: 7.3ms preprocess, 1715.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 2 males, 1291.4ms
# Speed: 5.3ms preprocess, 1291.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 2 males, 1081.8ms
# Speed: 4.8ms preprocess, 1081.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 females, 1 male, 1076.1ms
# Speed: 4.7ms preprocess, 1076.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 2 males, 1072.0ms
# Speed: 4.3ms preprocess, 1072.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 2 males, 1087.2ms
# Speed: 4.8ms preprocess, 1087.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 2 males, 1066.9ms
# Speed: 8.1ms preprocess, 1066.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 females, 2 males, 1075.9ms
# Speed: 4.9ms preprocess, 1075.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 2 males, 1080.9ms
# Speed: 7.9ms preprocess, 1080.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 2 males, 1072.6ms
# Speed: 5.0ms preprocess, 1072.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 2 males, 1461.6ms
# Speed: 4.4ms preprocess, 1461.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 2 males, 1720.4ms
# Speed: 5.9ms preprocess, 1720.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 2 males, 1610.8ms
# Speed: 8.2ms preprocess, 1610.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 2 males, 1082.7ms
# Speed: 5.0ms preprocess, 1082.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 2 males, 1069.4ms
# Speed: 4.6ms preprocess, 1069.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 2 males, 1061.0ms
# Speed: 6.5ms preprocess, 1061.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 2 males, 1067.5ms
# Speed: 4.9ms preprocess, 1067.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 2 males, 1070.7ms
# Speed: 4.4ms preprocess, 1070.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 2 males, 1069.6ms
# Speed: 4.0ms preprocess, 1069.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 2 males, 1111.2ms
# Speed: 8.2ms preprocess, 1111.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 females, 1 male, 1102.5ms
# Speed: 4.8ms preprocess, 1102.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 females, 2 males, 1198.5ms
# Speed: 5.3ms preprocess, 1198.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 females, 2 males, 1711.9ms
# Speed: 4.7ms preprocess, 1711.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 females, 2 males, 1708.6ms
# Speed: 4.8ms preprocess, 1708.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 females, 2 males, 1283.4ms
# Speed: 11.3ms preprocess, 1283.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 1 male, 1076.2ms
# Speed: 4.3ms preprocess, 1076.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 3 males, 1072.6ms
# Speed: 7.1ms preprocess, 1072.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 2 males, 1095.8ms
# Speed: 4.5ms preprocess, 1095.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 2 males, 1070.4ms
# Speed: 4.3ms preprocess, 1070.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 2 males, 1100.3ms
# Speed: 5.0ms preprocess, 1100.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 females, 1 male, 1093.4ms
# Speed: 5.3ms preprocess, 1093.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 females, 1 male, 1087.4ms
# Speed: 4.2ms preprocess, 1087.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 females, 1 male, 1090.0ms
# Speed: 5.2ms preprocess, 1090.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 females, 1 male, 1516.8ms
# Speed: 4.7ms preprocess, 1516.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 3 females, 1 male, 1740.1ms
# Speed: 5.7ms preprocess, 1740.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 females, 1 male, 1530.8ms
# Speed: 6.1ms preprocess, 1530.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 females, 1 male, 1070.9ms
# Speed: 4.6ms preprocess, 1070.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 females, 1 male, 1115.5ms
# Speed: 4.6ms preprocess, 1115.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 females, 1 male, 1099.7ms
# Speed: 4.5ms preprocess, 1099.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 females, 1 male, 1076.0ms
# Speed: 9.8ms preprocess, 1076.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 females, 1 male, 1089.4ms
# Speed: 5.4ms preprocess, 1089.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 females, 1 male, 1100.7ms
# Speed: 4.4ms preprocess, 1100.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 females, 1 male, 1095.0ms
# Speed: 3.8ms preprocess, 1095.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 females, 1 male, 1125.2ms
# Speed: 8.2ms preprocess, 1125.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 females, 1 male, 1370.9ms
# Speed: 4.3ms preprocess, 1370.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 2 males, 1736.0ms
# Speed: 4.9ms preprocess, 1736.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 females, 2 males, 1709.5ms
# Speed: 8.8ms preprocess, 1709.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 females, 2 males, 1125.3ms
# Speed: 10.2ms preprocess, 1125.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 females, 1 male, 1080.8ms
# Speed: 5.2ms preprocess, 1080.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 females, 1 male, 1078.9ms
# Speed: 6.4ms preprocess, 1078.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 females, 1 male, 1082.6ms
# Speed: 10.2ms preprocess, 1082.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 females, 1 male, 1101.0ms
# Speed: 4.1ms preprocess, 1101.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 females, 1 male, 1081.5ms
# Speed: 4.7ms preprocess, 1081.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 females, 1 male, 1087.7ms
# Speed: 4.4ms preprocess, 1087.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 females, 1 male, 1086.5ms
# Speed: 5.2ms preprocess, 1086.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 2 males, 1062.4ms
# Speed: 6.0ms preprocess, 1062.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 2 males, 1655.5ms
# Speed: 4.7ms preprocess, 1655.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 2 males, 1707.0ms
# Speed: 4.6ms preprocess, 1707.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 2 males, 1467.8ms
# Speed: 5.6ms preprocess, 1467.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 2 males, 1084.7ms
# Speed: 4.8ms preprocess, 1084.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 2 males, 1076.5ms
# Speed: 4.5ms preprocess, 1076.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 females, 2 males, 1105.8ms
# Speed: 4.6ms preprocess, 1105.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 females, 2 males, 1100.5ms
# Speed: 5.0ms preprocess, 1100.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 females, 2 males, 1098.7ms
# Speed: 5.2ms preprocess, 1098.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 females, 2 males, 1090.9ms
# Speed: 4.8ms preprocess, 1090.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)

# %%
cap.release()
writer.release()
cv2.destroyAllWindows()

print("/content/output_with_counting.mp4", OUTPUT_PATH)
# Out:
# /content/output_with_counting.mp4 /content/output_with_counting.mp4

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.12.0.88)
# Requirement already satisfied: numpy<2.3.0,>=2 in /usr/local/lib/python3.12/dist-packages (from opencv-python) (2.0.2)

# %%
pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.246-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.9.0+cpu)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.24.0+cpu)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.31.0)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Downloading ultralytics_thop-2.0.18-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2025.11.12)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Downloading ultralytics-8.3.246-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 17.6 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.18-py3-none-any.whl (28 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.3.246 ultralytics-thop-2.0.18

# %%
import cv2
import numpy as np
from ultralytics import YOLO
from ultralytics.solutions import ObjectCounter
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
MODEL_PATH = "/content/drive/MyDrive/YOLO11L train dataset/best (2).pt"
VIDEO_PATH = "/content/drive/MyDrive/cctv.mp4/market.mp4"
OUTPUT_PATH = "/content/output_with_counting.mp4"

model = YOLO(MODEL_PATH)

# %% [markdown]
# Video setup

# %%
cap = cv2.VideoCapture(VIDEO_PATH)
if not cap.isOpened():
    raise FileNotFoundError("Video not found")

w = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
h = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))

writer = cv2.VideoWriter(
    OUTPUT_PATH,
    cv2.VideoWriter_fourcc(*"mp4v"),
    fps,
    (w, h)
)

# %% [markdown]
# Entry Exit

# %%
frame_idx = 0

first_seen = {}        # id frame index first seen
last_seen = {}         # id frame index last seen
counted_entry = set()
counted_exit = set()

MIN_FRAMES_TO_COUNT = 8     #  must stay visible
EXIT_TIMEOUT = 20           #  must be gone

# %% [markdown]
# Logic / Loop

# %%
while True:
    ret, frame = cap.read()
    if not ret:
        break

    frame_idx += 1

    results = model.track(
        frame,
        persist=True,
        tracker="bytetrack.yaml",
        conf=0.4,
        iou=0.5
    )

    visible_ids = set()

    # Define class_names here from the model
    class_names = model.names

    if results[0].boxes.id is not None:
        boxes = results[0].boxes.xyxy.cpu().numpy()
        ids = results[0].boxes.id.cpu().numpy()
        classes = results[0].boxes.cls.cpu().numpy()

        for box, tid, cls in zip(boxes, ids, classes):
            tid = int(tid)
            visible_ids.add(tid)

            if tid not in first_seen:
                first_seen[tid] = frame_idx

            last_seen[tid] = frame_idx

            # -------------------------
            # ENTRY (STABLE)
            # -------------------------
            if (
                tid not in counted_entry and
                frame_idx - first_seen[tid] >= MIN_FRAMES_TO_COUNT
            ):
                counted_entry.add(tid)

            # Gender (FIXED)
            gender = class_names[int(cls)] # Changed CLASS_NAMES to class_names

            x1, y1, x2, y2 = map(int, box)
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
            cv2.putText(
                frame,
                f"ID {tid} {gender}",
                (x1, y1 - 8),
                cv2.FONT_HERSHEY_SIMPLEX,
                0.6,
                (0, 255, 0),
                2
            )

    # -------------------------
    # EXIT (STABLE)
    # -------------------------
    for tid in counted_entry:
        if (
            tid not in visible_ids and
            tid not in counted_exit and
            frame_idx - last_seen.get(tid, 0) >= EXIT_TIMEOUT
        ):
            counted_exit.add(tid)

    entered = len(counted_entry)
    exited = len(counted_exit)
    current = entered - exited

    cv2.putText(
        frame,
        f"Entered: {entered}   Exited: {exited}   Current: {current}",
        (30, 40),
        cv2.FONT_HERSHEY_SIMPLEX,
        1,
        (0, 0, 255),
        3
    )

    writer.write(frame)
# Out:
# Streaming output truncated to the last 5000 lines.
# 0: 640x480 1 female, 1 male, 2027.9ms
# Speed: 6.2ms preprocess, 2027.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 male, 1349.1ms
# Speed: 4.6ms preprocess, 1349.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 male, 1347.3ms
# Speed: 8.6ms preprocess, 1347.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 male, 1356.2ms
# Speed: 4.5ms preprocess, 1356.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 1 male, 1342.3ms
# Speed: 4.0ms preprocess, 1342.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 1 male, 1352.4ms
# Speed: 4.5ms preprocess, 1352.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 male, 1361.5ms
# Speed: 4.5ms preprocess, 1361.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 male, 1347.2ms
# Speed: 5.3ms preprocess, 1347.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 male, 2107.9ms
# Speed: 6.0ms preprocess, 2107.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 male, 2132.7ms
# Speed: 5.1ms preprocess, 2132.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 male, 1443.1ms
# Speed: 5.5ms preprocess, 1443.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 male, 1382.0ms
# Speed: 7.5ms preprocess, 1382.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 male, 1360.2ms
# Speed: 3.5ms preprocess, 1360.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 male, 1381.3ms
# Speed: 4.6ms preprocess, 1381.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 male, 1381.0ms
# Speed: 4.3ms preprocess, 1381.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 male, 
9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 3 males, 1836.6ms
# Speed: 7.6ms preprocess, 1836.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 3 males, 1369.8ms
# Speed: 5.0ms preprocess, 1369.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 3 males, 1359.5ms
# Speed: 5.0ms preprocess, 1359.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 3 males, 1373.8ms
# Speed: 8.5ms preprocess, 1373.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 3 males, 1391.1ms
# Speed: 6.5ms preprocess, 1391.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 3 males, 1431.5ms
# Speed: 4.8ms preprocess, 1431.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 3 males, 1383.0ms
# Speed: 9.0ms preprocess, 1383.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 males, 1653.1ms
# Speed: 5.3ms preprocess, 1653.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 males, 2156.4ms
# Speed: 9.1ms preprocess, 2156.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 males, 1758.9ms
# Speed: 7.8ms preprocess, 1758.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 males, 1354.0ms
# Speed: 5.1ms preprocess, 1354.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 males, 1364.3ms
# Speed: 7.1ms preprocess, 1364.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 males, 1353.3ms
# Speed: 4.6ms preprocess, 1353.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 males, 1353.3ms
# Speed: 5.4ms preprocess, 1353.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 2 males, 1369.9ms
# Speed: 4.9ms preprocess, 1369.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 3 males, 1360.2ms
# Speed: 4.6ms preprocess, 1360.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 3 males, 1640.9ms
# Speed: 4.7ms preprocess, 1640.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 2 males, 2207.8ms
# Speed: 8.7ms preprocess, 2207.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 3 males, 1808.7ms
# Speed: 11.7ms preprocess, 1808.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 3 males, 1436.0ms
# Speed: 6.9ms preprocess, 1436.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 3 males, 1421.4ms
# Speed: 5.5ms preprocess, 1421.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 3 males, 1417.5ms
# Speed: 5.1ms preprocess, 1417.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 2 males, 1364.7ms
# Speed: 5.1ms preprocess, 1364.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 2 males, 1369.6ms
# Speed: 4.8ms preprocess, 1369.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 3 males, 1406.9ms
# Speed: 5.3ms preprocess, 1406.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 3 males, 1787.4ms
# Speed: 4.8ms preprocess, 1787.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 3 males, 2185.2ms
# Speed: 7.9ms preprocess, 2185.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 3 males, 1628.8ms
# Speed: 8.0ms preprocess, 1628.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 3 males, 1357.4ms
# Speed: 8.6ms preprocess, 1357.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 4 males, 1380.2ms
# Speed: 6.2ms preprocess, 1380.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 4 males, 1368.2ms
# Speed: 4.5ms preprocess, 1368.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 4 males, 1371.7ms
# Speed: 4.5ms preprocess, 1371.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 2 males, 1421.2ms
# Speed: 6.9ms preprocess, 1421.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 3 males, 1374.2ms
# Speed: 6.7ms preprocess, 1374.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 female, 3 males, 1897.3ms
# Speed: 6.6ms preprocess, 1897.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 3 males, 2186.0ms
# Speed: 6.6ms preprocess, 2186.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 3 males, 1548.5ms
# Speed: 7.4ms preprocess, 1548.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 3 males, 1391.1ms
# Speed: 5.8ms preprocess, 1391.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 3 males, 1389.0ms
# Speed: 4.8ms preprocess, 1389.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 3 males, 1351.3ms
# Speed: 4.9ms preprocess, 1351.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 3 males, 1347.3ms
# Speed: 5.9ms preprocess, 1347.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 3 males, 1354.0ms
# Speed: 4.8ms preprocess, 1354.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 3 males, 1357.1ms
# Speed: 4.6ms preprocess, 1357.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 3 males, 1952.7ms
# Speed: 6.3ms preprocess, 1952.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 3 males, 2172.2ms
# Speed: 4.5ms preprocess, 2172.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 3 males, 1528.3ms
# Speed: 4.8ms preprocess, 1528.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 3 males, 1376.2ms
# Speed: 4.9ms preprocess, 1376.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 3 males, 1375.6ms
# Speed: 5.0ms preprocess, 1375.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 3 males, 1387.2ms
# Speed: 4.8ms preprocess, 1387.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)

# %%
cap.release()
writer.release()
cv2.destroyAllWindows()

print("/content/output_with_counting.mp4", OUTPUT_PATH)
# Out:
# /content/output_with_counting.mp4 /content/output_with_counting.mp4

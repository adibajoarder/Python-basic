# %%
import pandas as pd
import numpy as np
df = pd.read_csv('/content/MedER_Dataset_English_Translated.csv')
df.head()
# Out:
#                                     Medical Text_eng  \
# 0  Fexofenadine treats allergy symptoms, includin...
# 1  Tufnil is mainly used to relieve pain such as ...
# 2  Amoxicillin is a penicillin-based antibiotic (...
# 3   Atropine is a tropane alkaloid that is common...
# 4  Azithromycin belongs to a group of drugs calle...
#
#   Medicine\ Chemical Name_eng                 Organ_eng  \
# 0                Fexofenadine                Eyes, nose
# 1         Tafenil, Tolfenamic                       NaN
# 2                 Amoxicillin                       NaN
# 3                    Atropine                       NaN
# 4                Azithromycin  Skin, respiratory system
#
#                                         Disease_eng Hormones_eng  \
# 0   Itching, sneezing, irritation, itching, allergy    Histamine
# 1                                       Pain, fever          NaN
# 2                               Bacterial infection          NaN
# ...

# %%
print(df.head(5))
# Out:
#                                     Medical Text_eng  \
# 0  Fexofenadine treats allergy symptoms, includin...
# 1  Tufnil is mainly used to relieve pain such as ...
# 2  Amoxicillin is a penicillin-based antibiotic (...
# 3   Atropine is a tropane alkaloid that is common...
# 4  Azithromycin belongs to a group of drugs calle...
#
#   Medicine\ Chemical Name_eng                 Organ_eng  \
# 0                Fexofenadine                Eyes, nose
# 1         Tafenil, Tolfenamic                       NaN
# 2                 Amoxicillin                       NaN
# 3                    Atropine                       NaN
# 4                Azithromycin  Skin, respiratory system
#
#                                         Disease_eng Hormones_eng  \
# 0   Itching, sneezing, irritation, itching, allergy    Histamine
# 1                                       Pain, fever          NaN
# 2                               Bacterial infection          NaN
# ...

# %%
print(df.columns)
# Out:
# Index(['Medical Text_eng', 'Medicine\ Chemical Name_eng', 'Organ_eng',
#        'Disease_eng', 'Hormones_eng', 'Pharmacological Class_eng',
#        'Common Medical Terms_eng'],
#       dtype='object')

# %%
print(df.shape)
# Out:
# (2980, 7)

# %%
df.columns
print(df[r'Medicine\ Chemical Name_eng'],['Indication_eng'],['Side Effects_eng'])
# Out:
# 0              Fexofenadine
# 1       Tafenil, Tolfenamic
# 2               Amoxicillin
# 3                  Atropine
# 4              Azithromycin
#                ...
# 2975                    NaN
# 2976                    NaN
# 2977                    NaN
# 2978                    NaN
# 2979                    NaN
# Name: Medicine\ Chemical Name_eng, Length: 2980, dtype: object ['Indication_eng'] ['Side Effects_eng']

# %%
print(df.iloc[1])
# Out:
# Medical Text_eng               Tufnil is mainly used to relieve pain such as ...
# Medicine\ Chemical Name_eng                                  Tafenil, Tolfenamic
# Organ_eng                                                                    NaN
# Disease_eng                                                          Pain, fever
# Hormones_eng                                                                 NaN
# Pharmacological Class_eng                                                    NaN
# Common Medical Terms_eng                                                     NaN
# Name: 1, dtype: object

# %%
df.describe()
# Out:
#                                          Medical Text_eng  \
# count                                                2980
# unique                                               2956
# top     Avoid taking fexofenadine with fruit juices su...
# freq                                                    2
#
#        Medicine\ Chemical Name_eng Organ_eng Disease_eng Hormones_eng  \
# count                         2659      1560        1502         1293
# unique                         292       636         995          184
# top                       Oxytocin     Brain     Allergy  Vasopressin
# freq                           105       145          50          117
#
#        Pharmacological Class_eng Common Medical Terms_eng
# count                       1370                     1666
# unique                       261                     1049
# top             Peptide hormones                 Medicine
# freq                         220                       88

# %%
print('Summary Statistics for new_df:')
display(new_df.describe(include='all'))
# Out:
# Summary Statistics for new_df:
#        Disease_eng  Indication_eng
# count         1502             0.0
# unique         995             NaN
# top        Allergy             NaN
# freq            50             NaN
# mean           NaN             NaN
# std            NaN             NaN
# min            NaN             NaN
# 25%            NaN             NaN
# 50%            NaN             NaN
# 75%            NaN             NaN
# max            NaN             NaN

# %%
print('\nDataFrame Information for new_df:')
new_df.info()
# Out:
# DataFrame Information for new_df:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2980 entries, 0 to 2979
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Disease_eng     1502 non-null   object
#  1   Indication_eng  0 non-null      float64
# dtypes: float64(1), object(1)
# memory usage: 46.7+ KB

# %%
print(new_df['Disease_eng'].head())
# Out:
# 0     Itching, sneezing, irritation, itching, allergy
# 1                                         Pain, fever
# 2                                 Bacterial infection
# 3                           Inflammation, fever, pain
# 4                                           Pneumonia
# Name: Disease_eng, dtype: object

# %%
print(new_df.columns)
# Out:
# Index(['Disease_eng', 'Indication_eng'], dtype='object')

# %%
df.sort_values(by='Disease_eng')
# Out:
#                                        Medical Text_eng  \
# 601   Buscopan is an anticholinergic drug used to tr...
# 1998  Spironolactone has antiandrogenic activity. Fo...
# 1972  Bromocriptine is used to treat acromegaly and ...
# 1203  Patients should be alert to possible allergic ...
# 1143  Diclofenac is not recommended if you have a kn...
# ...                                                 ...
# 2943  The patient's eyes are burning. Give eye drops...
# 2944  The patient is having ear pain. Give ear drops...
# 2945  The patient's nose is dripping. Give nasal dro...
# 2968  The patient suffered a head injury and the doc...
# 2975  The patient's spleen has become enlarged and t...
#
#      Medicine\ Chemical Name_eng                         Organ_eng  \
# 601                     Buscopan       Stomach, esophagus, bladder
# 1998              Spironolactone                              Skin
# 1972               Bromocriptine   Pituitary gland, breast, gonads
# ...

# %%
new_df = pd.DataFrame(df,columns=['Disease_eng','Indication_eng','Side Effects_eng'])
print(new_df)
# Out:
#                                            Disease_eng  Indication_eng  \
# 0      Itching, sneezing, irritation, itching, allergy             NaN
# 1                                          Pain, fever             NaN
# 2                                  Bacterial infection             NaN
# 3                            Inflammation, fever, pain             NaN
# 4                                            Pneumonia             NaN
# ...                                                ...             ...
# 2975                                               NaN             NaN
# 2976                                     Kidney stones             NaN
# 2977                                 Bladder infection             NaN
# 2978                         Blockage in blood vessels             NaN
# 2979                                           Tonsils             NaN
#
#       Side Effects_eng
# 0                  NaN
# 1                  NaN
# 2                  NaN
# ...
